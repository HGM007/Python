# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.array([100,1000,5000,10000,15000,20000,25000,30000,35000,40000,45000,50000])
y=np.array([0.002000 ,0.021000 ,0.106000 ,0.260000,0.401000,0.625000 ,0.792000,1.108000 ,1.308000,1.584000 ,1.906000 ,2.237000 ])

plt.title("Selection sort")
plt.xlabel("size_of_array")
plt.ylabel("Time")

plt.plot(x,y)
plt.show()

# %%
x=np.array([100,1000,5000,10000,15000,20000,25000,30000,35000,40000])
y=np.array([ 0.000549,0.027532 ,0.027532 ,3.581998 ,4.302000,7.257000, 10.538000,14.726000,19.958000,25.627000])

plt.title("Radix sort")
plt.xlabel("size_of_array")
plt.ylabel("Time")

plt.plot(x,y)
plt.show()

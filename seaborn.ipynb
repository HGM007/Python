# %% [markdown]
# ## Himanshu G Marekar

# %%
import pandas as pd
import matplotlib.pyplot as mpl
import warnings
import seaborn as sb
import numpy as np
# %matplotlib inline

# %%
warnings.filterwarnings('ignore')

# %%
S=pd.read_csv("bank_marketing.csv")

# %%
S.head()
# Out:
#       banking marketing Unnamed: 1                    Unnamed: 2 Unnamed: 3  \
# 0  customer id and age.        NaN  Customer salary and balance.        NaN
# 1            customerid        age                        salary    balance
# 2                     1         58                        100000       2143
# 3                     2         44                         60000         29
# 4                     3         33                        120000          2
#
#                                           Unnamed: 4              Unnamed: 5  \
# 0  Customer marital status and job with education...                     NaN
# 1                                            marital                  jobedu
# 2                                            married     management,tertiary
# 3                                             single    technician,secondary
# 4                                            married  entrepreneur,secondary
#
# ...

# %%
#data cleaning
S=pd.read_csv("bank_marketing.csv",skiprows=2)

# %%
S.dtypes
# Out:
# customerid      int64
# age           float64
# salary          int64
# balance         int64
# marital        object
# jobedu         object
# targeted       object
# default        object
# housing        object
# loan           object
# contact        object
# day             int64
# month          object
# duration       object
# campaign        int64
# pdays           int64
# previous        int64
# poutcome       object
# response       object
# dtype: object

# %%
S.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# ...

# %%
#dividing "jobedu" colm into job and education catagories
#extract job in newly created 'job' colm free "jobedu" colm

S['job']=S.jobedu.apply(lambda x:x.split(',')[0])

#extract edu in newly created 'edu' colm free "jobedu" colm
S['edu']=S.jobedu.apply(lambda x:x.split(',')[0])

# %%
S.head()

#for removing jobedu
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  ... day      month duration campaign  pdays  \
# 0      yes      no     yes   no  ...   5  may, 2017  261 sec        1     -1
# 1      yes      no     yes   no  ...   5  may, 2017  151 sec        1     -1
# 2      yes      no     yes  yes  ...   5  may, 2017   76 sec        1     -1
# 3       no      no     yes   no  ...   5  may, 2017   92 sec        1     -1
# 4       no      no      no   no  ...   5  may, 2017  198 sec        1     -1
#
#    previous  poutcome response           job           edu
# ...

# %%
#drop the jobedu  colm from dataframe
S.drop['jobedu',axis=1,inplace=True]
# Out:
#   Input In [37]
#     S.drop['jobedu',axis=1,inplace=True]
#                         ^
# SyntaxError: invalid syntax

# %%
S.head()
#dropped
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  ... day      month duration campaign  pdays  \
# 0      yes      no     yes   no  ...   5  may, 2017  261 sec        1     -1
# 1      yes      no     yes   no  ...   5  may, 2017  151 sec        1     -1
# 2      yes      no     yes  yes  ...   5  may, 2017   76 sec        1     -1
# 3       no      no     yes   no  ...   5  may, 2017   92 sec        1     -1
# 4       no      no      no   no  ...   5  may, 2017  198 sec        1     -1
#
#    previous  poutcome response           job           edu
# ...

# %%
#counts the missing values in age colm
S.isnull().sum()
# Out:
# customerid     0
# age           20
# salary         0
# balance        0
# marital        0
# jobedu         0
# targeted       0
# default        0
# housing        0
# loan           0
# contact        0
# day            0
# month         50
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# response      30
# job            0
# edu            0
# dtype: int64

# %%
#ptr shape of df
S.shape
# Out:
# (45211, 21)

# %%
#ignore the missing values as count is less

S1=S[~S.age.isnull()].copy()

S1
# Out:
#        customerid   age  salary  balance   marital                  jobedu  \
# 0               1  58.0  100000     2143   married     management,tertiary
# 1               2  44.0   60000       29    single    technician,secondary
# 2               3  33.0  120000        2   married  entrepreneur,secondary
# 3               4  47.0   20000     1506   married     blue-collar,unknown
# 4               5  33.0       0        1    single         unknown,unknown
# ...           ...   ...     ...      ...       ...                     ...
# 45206       45207  51.0   60000      825   married     technician,tertiary
# 45207       45208  71.0   55000     1729  divorced         retired,primary
# 45208       45209  72.0   55000     5715   married       retired,secondary
# 45209       45210  57.0   20000      668   married   blue-collar,secondary
# 45210       45211  37.0  120000     2971   married  entrepreneur,secondary
#
# ...

# %%
#check
S1.isnull().sum()
# Out:
# customerid     0
# age            0
# salary         0
# balance        0
# marital        0
# jobedu         0
# targeted       0
# default        0
# housing        0
# loan           0
# contact        0
# day            0
# month         50
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# response      30
# job            0
# edu            0
# dtype: int64

# %%
S1.shape
# Out:
# (45191, 21)

# %%
S1.month.isnull().sum()
# Out:
# 50

# %%
S1.month.value_counts()
# Out:
# may, 2017    13740
# jul, 2017     6885
# aug, 2017     6235
# jun, 2017     5333
# nov, 2017     3967
# apr, 2017     2930
# feb, 2017     2646
# jan, 2017     1402
# oct, 2017      737
# sep, 2017      576
# mar, 2017      476
# dec, 2017      214
# Name: month, dtype: int64

# %%
M=S1.month.mode()[0]
M
# Out:
# 'may, 2017'

# %%
# lets see null val in colm 1
S1.month.fillna(M,inplace=True)

# %%
S1.month.isnull().sum()
# Out:
# 0

# %%
# handling missing val in response colm

# %%
# handling outliers

# %%
S1.salary.describe()
# Out:
# count     45191.000000
# mean      57005.974641
# std       32084.253154
# min           0.000000
# 25%       20000.000000
# 50%       60000.000000
# 75%       70000.000000
# max      120000.000000
# Name: salary, dtype: float64

# %%
#5 no. summary
sb.boxplot(S1.salary)
mpl.show()

# %%
sb.boxplot(S1.balance)
mpl.show()

# %%
#ptrthe quantile
S1.balance.quantile([0.95])
#95%
# Out:
# 0.95    5768.0
# Name: balance, dtype: float64

# %%
# S1=S[~S.duration.isnull()].copy()
S1.duration = S1.duration.apply(lambda x: float(x.split()[0])/60  
if x.find("sec")>0 
else float(x.split()[0]) )

S1.duration
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [33], in <cell line: 2>()
#       1 # S1=S[~S.duration.isnull()].copy()
# ----> 2 S1.duration = S1.duration.apply(lambda x: float(x.split()[0])/60
#       3 if x.find("sec")>0
#       4 else float(x.split()[0]) )
#       6 S1.duration
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
# ...

# %%
# Sorting 
S1.sort_values(by=['response'])
# Out:
#        customerid   age  salary  balance   marital                   jobedu  \
# 0               1  58.0  100000     2143   married      management,tertiary
# 27694       27695  35.0   60000     8883   married  self-employed,secondary
# 27695       27696  36.0  100000        0   married      management,tertiary
# 27696       27697  32.0   60000      785    single      technician,tertiary
# 27697       27698  49.0   60000     1077   married      technician,tertiary
# ...           ...   ...     ...      ...       ...                      ...
# 39099       39100  29.0   60000      476    single   self-employed,tertiary
# 39504       39505  38.0   50000      755   married         admin.,secondary
# 39976       39977  39.0   50000      150   married         admin.,secondary
# 40397       40398  69.0   55000     1806  divorced        retired,secondary
# 40774       40775  70.0   20000     3075   married      blue-collar,primary
#
# ...

# %%
S1["response"].fillna("no",inplace=True)
S1.response.isnull().sum()
# Out:
# 0
